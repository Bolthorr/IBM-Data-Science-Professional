# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Justin Carter**
# Current occupation: Real-time data analyst for deepwater oil & gas exploration

# %% [markdown]
# *Why am I interested in data science?
# I enjoy analyzing trends over time. Data science is the tool to quantify and visualize conditions over time. This can be ocean water temperatures, costs associated with university attendence, the participation in leisure activities, etc...  This provides us with understanding of the changes in the world and cultures around us, which can aid in our ability to adapt over time.*

# %% [markdown]
# ### The code outputs a message to the people who read and/or grade this project.

# %%
print("Hello Grader! I hope you are having an excellent day.")
# Out:
# Hello Grader! I hope you are having an excellent day.

# %% [markdown]
# > Block Quotes
# >
# >> A fellow jumped off a high wall,
# >> And had a most terrible fall.
# >> He went back to bed,
# >> With a bump on his head,
# >> That's why you don't jump off a wall.
# >
# > The End.
#
#
# 1. Is a hyperlink [Duck Duck Go](https://duckduckgo.com).
# 2. ~~This is strikethrough~~
# 4. This is <sup>superscript</sup>
# 5. This is <sub>subscript</sub>
# 6. <mark>Finally, highlighted text</mark>
